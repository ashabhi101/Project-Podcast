# %%
import pandas as pd
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import spacy
import os
import glob
import matplotlib.pyplot as plt

# %%
os.listdir('/Users/abhil/project_podcast/Data/')
# Out:
# ['.DS_Store',
#  'Breaking Down Bureaucracy and Building Up Workers.txt',
#  'To build grit, go back to basics.txt',
#  'Mastering the Art of Persuasion.txt',
#  'Creating more resilient Supply Chains.txt',
#  'Why work friends are worth it.txt']

# %%
with open('/Users/abhil/project_podcast/Data/Creating more resilient Supply Chains.txt', encoding='utf-8') as f:
    text = f.read()

# %%
from unicodedata2 import normalize as nz
text = str(nz('NFKD', text).encode('utf-8', 'ignore'))

# %%
text = text.replace('\xa0', ' ')

# %%
text
# Out:
# 'ALISON BEARD:  Welcome to the HBR IdeaCast from Harvard Business Review.  I’m Alison Beard.\nIf you’ve had trouble buying toilet paper, or cleaning supplies, or even car and computer parts over the past few months, you’ve been keenly aware of something that consumers rarely think about, corporate supply chains.\nThe COVID-19 pandemic with its border and business closures have showed us just how hard it is to keep making things and getting them into the hands of end users in a timely fashion.  Most production is global and increasingly complex, and one kink in the system, never mind the worse health and economic crisis in a century, can wreak havoc.  Companies simply can’t meet demand.  We go without goods from nice to have like frozen strawberries, to necessities like medicine.  And the organizations lose revenue – sometimes so much that it’s difficult to stay in business.\nOur guest today studies supply chains and ideas for how they can be improved.  Our guest today studies supply chains and has ideas for how they can be improved and made more resilient for future crisis.  Willy Shih is a professor at Harvard Business School and he wrote the HBR article, “Supply Chains in a Post-Pandemic World.”  Willy, thanks so much for being on the show.\nWILLY SHIH:  Thank you for inviting me.\nALISON BEARD:  So, for those of us who didn’t study operations in business school and don’t think about these issues that often, could you give us just a quick explanation of how global supply chains work nowadays?\nWILLY SHIH:  Well, Alison, these days global supply chains as you mentioned, are very complex.  And that’s firms tend to rely on a network of suppliers for components or subassemblies or raw materials.  And because we have experienced an era of rapid globalization, which has really been marked by really low cost and very convenient communications, and shipping, firms have tended to cast a wide net geographically when looking for sources of supply.\nAnd these have been driven by cost, they’ve also been driven by specialization.  So, for example when you have very complex products like a phone, or a laptop computer, manufacturers will rely on specialists who might be in a distant part of the world.  And until this pandemic, that was fine because we had very reliable and very efficient and more importantly, very predictable transportation links.\nWhat happened when the pandemic hit, it suddenly exposed the  complex network of suppliers that many firms use.  OK.  And if you’re assembling something, like an automobile, or a notebook computer, or a washing machine, or a freezer, you only need to be short one part to not be able to assemble your product.\nALISON BEARD:  And did we see any hints of this problem before the pandemic?  For example, when natural disasters would hit certain parts of the world?\nWILLY SHIH:  Oh certainly.  We’ve seen a number of examples of these which have served as a warning.  So, for example, back in 2011, the East Japan earthquake and tsunami took off a number of suppliers in Japan – around Naka, Japan – offline.  And some of those suppliers were critical for these supply chains.  For example, there was one company there who made the material that made automotive black paint sparkle.\nAnd it turns out every auto maker relied on this one company who may have been several tiers down in the supply network, so they didn’t realize they were all reliant on this one company.  So, when that company went down, all of a sudden nobody could paint cars black anymore.\nThere were also floods in Thailand later that year, which caused a massive disruption to the disc drive supply chain for the whole world.  Because Thailand manufactured about half the world’s disc drives at that time.  That should have been a signal to people that wait a minute, we have these really concentrated dependencies in parts of the world that we kind of take for granted that they can deliver to us on time, in full and suddenly, one day comes along whe ...

# %%
full_name_pattern = '([A-Z]+[\s]+[A-Z]+[\s]+[A-Z]+):(.*)?'

# %%
transcript_cleaned = re.sub('\n{2,4}(?![A-Z]{2,})', ' ', text)

# %%
transcript_cleaned
# Out:
# 'ALISON BEARD:  Welcome to the HBR IdeaCast from Harvard Business Review.  I’m Alison Beard.\nIf you’ve had trouble buying toilet paper, or cleaning supplies, or even car and computer parts over the past few months, you’ve been keenly aware of something that consumers rarely think about, corporate supply chains.\nThe COVID-19 pandemic with its border and business closures have showed us just how hard it is to keep making things and getting them into the hands of end users in a timely fashion.  Most production is global and increasingly complex, and one kink in the system, never mind the worse health and economic crisis in a century, can wreak havoc.  Companies simply can’t meet demand.  We go without goods from nice to have like frozen strawberries, to necessities like medicine.  And the organizations lose revenue – sometimes so much that it’s difficult to stay in business.\nOur guest today studies supply chains and ideas for how they can be improved.  Our guest today studies supply chains and has ideas for how they can be improved and made more resilient for future crisis.  Willy Shih is a professor at Harvard Business School and he wrote the HBR article, “Supply Chains in a Post-Pandemic World.”  Willy, thanks so much for being on the show.\nWILLY SHIH:  Thank you for inviting me.\nALISON BEARD:  So, for those of us who didn’t study operations in business school and don’t think about these issues that often, could you give us just a quick explanation of how global supply chains work nowadays?\nWILLY SHIH:  Well, Alison, these days global supply chains as you mentioned, are very complex.  And that’s firms tend to rely on a network of suppliers for components or subassemblies or raw materials.  And because we have experienced an era of rapid globalization, which has really been marked by really low cost and very convenient communications, and shipping, firms have tended to cast a wide net geographically when looking for sources of supply.\nAnd these have been driven by cost, they’ve also been driven by specialization.  So, for example when you have very complex products like a phone, or a laptop computer, manufacturers will rely on specialists who might be in a distant part of the world.  And until this pandemic, that was fine because we had very reliable and very efficient and more importantly, very predictable transportation links.\nWhat happened when the pandemic hit, it suddenly exposed the  complex network of suppliers that many firms use.  OK.  And if you’re assembling something, like an automobile, or a notebook computer, or a washing machine, or a freezer, you only need to be short one part to not be able to assemble your product.\nALISON BEARD:  And did we see any hints of this problem before the pandemic?  For example, when natural disasters would hit certain parts of the world?\nWILLY SHIH:  Oh certainly.  We’ve seen a number of examples of these which have served as a warning.  So, for example, back in 2011, the East Japan earthquake and tsunami took off a number of suppliers in Japan – around Naka, Japan – offline.  And some of those suppliers were critical for these supply chains.  For example, there was one company there who made the material that made automotive black paint sparkle.\nAnd it turns out every auto maker relied on this one company who may have been several tiers down in the supply network, so they didn’t realize they were all reliant on this one company.  So, when that company went down, all of a sudden nobody could paint cars black anymore.\nThere were also floods in Thailand later that year, which caused a massive disruption to the disc drive supply chain for the whole world.  Because Thailand manufactured about half the world’s disc drives at that time.  That should have been a signal to people that wait a minute, we have these really concentrated dependencies in parts of the world that we kind of take for granted that they can deliver to us on time, in full and suddenly, one day comes along whe ...

# %%
text_groups = re.findall('([A-Z]+[\s]+[A-Z]+[\sA-Z]*):(.*)?', transcript_cleaned)

# %%
conv_df = pd.DataFrame(columns = ['Speaker', 'Dialogue'])

for group in text_groups:
    conv_df = conv_df.append({'Speaker' :group[0], 'Dialogue':group[1]}, ignore_index = True)

# %%
conv_df
# Out:
#          Speaker                                           Dialogue
# 0   ALISON BEARD    Welcome to the HBR IdeaCast from Harvard Bus...
# 1     WILLY SHIH                         Thank you for inviting me.
# 2   ALISON BEARD    So, for those of us who didn’t study operati...
# 3     WILLY SHIH    Well, Alison, these days global supply chain...
# 4   ALISON BEARD    And did we see any hints of this problem bef...
# 5     WILLY SHIH    Oh certainly.  We’ve seen a number of exampl...
# 6   ALISON BEARD    Yeah.  But as you mentioned, global corporat...
# 7     WILLY SHIH    Well, we have a lot of talk about how people...
# 8   ALISON BEARD    OK.  So, let’s look forward to solutions.  A...
# 9     WILLY SHIH    Well, I think the first step obviously is ma...
# 10  ALISON BEARD    Right.  And even once you’ve identified all ...
# 11    WILLY SHIH    Risk assessment is really key.  Because as y...
# 12  ALISON BEARD    Yeah.  So, the solutions you’ve mentioned so...
# 13    WILLY SHIH    Process improvement is my favorite one.  Esp...
# 14  ALISON BEARD    So, how do we incentivize companies and thei...
# 15    WILLY SHIH    Well, I think one of the things that I’ve ob...
# 16  ALISON BEARD    In a way it seems like companies should be t...
# 17    WILLY SHIH     It’s going to take using all these things. ...
# 18  ALISON BEARD    We also have approached this issue very much...
# 19    WILLY SHIH    You know, it’s kind of a two-way street.  Pe...
# 20  ALISON BEARD    This obviously is a topic that’s highly rele...
# 21    WILLY SHIH    Well, even software and services businesses ...
# 22  ALISON BEARD    You mentioned how long many of these changes...
# 23    WILLY SHIH    One of the things that I think has been very...
# 24  ALISON BEARD    Well, hopefully organizations and consumers ...
# 25    WILLY SHIH                                         Thank you.
# 26  ALISON BEARD    That’s Willy Shih, Professor at Harvard Busi...

# %%
conv_df.describe()
# Out:
#              Speaker                                           Dialogue
# count             27                                                 27
# unique             2                                                 27
# top     ALISON BEARD    Risk assessment is really key.  Because as y...
# freq              14                                                  1

# %%
conv_df.Speaker.value_counts()
list(conv_df.Speaker.unique())
# Out:
# ['ALISON BEARD', 'WILLY SHIH']

# %%
def text_by_author(df):
    unique_names = list(df.Speaker.unique())
    speaker_text = []
    for speaker in unique_names:
        
        speaker_text.append([speaker, df[df['Speaker'] == speaker]['Dialogue'].str.cat()])
        
    return speaker_text

# %%
author_text = text_by_author(conv_df)

# %%
conv_df['Letter_Count'] = conv_df['Dialogue'].apply(lambda x: len(x))
conv_df['Word_Count'] = conv_df['Dialogue'].apply(lambda x: len(x.split(' ')))

# %%
conv_df.to_pickle('conv_df.pkl')

# %%
# Most common number of words in a message
plt.figure(figsize=(15, 2)) # To ensure that the bar plot fits in the output cell of a Jupyter notebook
word_count_value_counts = conv_df['Word_Count'].value_counts()
top_40_word_count_value_counts = word_count_value_counts.head(40)
top_40_word_count_value_counts.plot.bar()
plt.xlabel('Word Count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Building Summarizer Model with Spacy

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
guest_text = author_text[1][1]

# %%
guest_text = nlp(guest_text)

# %%
corpus = [sent.text.lower() for sent in guest_text.sents ]
cv = CountVectorizer(stop_words=list(STOP_WORDS))   
cv_fit=cv.fit_transform(corpus)    
word_list = cv.get_feature_names();    
count_list = cv_fit.toarray().sum(axis=0)
word_frequency = dict(zip(word_list,count_list))
# Out:
# /Users/abhil/anaconda3/envs/podcast/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
val=sorted(word_frequency.values())
higher_word_frequencies = [word for word,freq in word_frequency.items() if freq in val[-3:]]
print("\nWords with higher frequencies: ", higher_word_frequencies)
# gets relative frequency of words
higher_frequency = val[-1]
for word in word_frequency.keys():  
    word_frequency[word] = (word_frequency[word]/higher_frequency)
# Out:
# Words with higher frequencies:  ['companies', 'supply', 'think']

# %%
sentence_rank={}
for sent in guest_text.sents:
    for word in sent :       
        if word.text.lower() in word_frequency.keys():            
            if sent in sentence_rank.keys():
                sentence_rank[sent]+=word_frequency[word.text.lower()]
            else:
                sentence_rank[sent]=word_frequency[word.text.lower()]
top_sentences=(sorted(sentence_rank.values())[::-1])
top_sent=top_sentences[:3]

# %%
summary=[]
for sent,strength in sentence_rank.items():  
    if strength in top_sent:
        summary.append(sent)
    else:
        continue
for i in summary:
    print(i,end=" ")
# Out:
# If you think about why manufacturers outsourced their supply to Asia or East Asia, or South Asia in the first point, place, it was to save costs.   Well, I think one of the things that I’ve observed in this pandemic and the recession that’s going with it, is that companies who use the crisis as a way of unfreezing their ways of working, unfreezing their organizational processes, adopting new ways of doing things.   We’ve seen a lot of pivots where firms have really moved into, moved into new areas, moved into new ways of serving customers as well.

# %%
guest_text
# Out:
#   Thank you for inviting me.  Well, Alison, these days global supply chains as you mentioned, are very complex.  And that’s firms tend to rely on a network of suppliers for components or subassemblies or raw materials.  And because we have experienced an era of rapid globalization, which has really been marked by really low cost and very convenient communications, and shipping, firms have tended to cast a wide net geographically when looking for sources of supply.  Oh certainly.  We’ve seen a number of examples of these which have served as a warning.  So, for example, back in 2011, the East Japan earthquake and tsunami took off a number of suppliers in Japan – around Naka, Japan – offline.  And some of those suppliers were critical for these supply chains.  For example, there was one company there who made the material that made automotive black paint sparkle.  Well, we have a lot of talk about how people need to build more resilient supply chains.  And I think this is a good opportunity for people to go back and examine their supply chains and understand where the vulnerabilities are.  But I think consumers, especially in this post pandemic recession, aren’t going to want to necessarily pay more.  So, I think that causes the dilemma for a lot of companies.  Well, I think the first step obviously is mapping your supply chain.  And while that sounds obvious, it’s actually a much harder task than most people appreciate.  And the reason is because these days with kind of the division of labor and specialization of many firms inside the supply chain, we have many tiers.  Risk assessment is really key.  Because as you look through those tiers then you can say, well, how easy is it for me to substitute somebody else?  Are there alternative sources of supply?  Find those ones where they have a high revenue impact to me, if one or more of those suppliers is unable to deliver for whatever reason.  Process improvement is my favorite one.  Especially for companies like in high cost regions like the U.S. or Europe.  If you think about why manufacturers outsourced their supply to Asia or East Asia, or South Asia in the first point, place, it was to save costs.  Well, I think one of the things that I’ve observed in this pandemic and the recession that’s going with it, is that companies who use the crisis as a way of unfreezing their ways of working, unfreezing their organizational processes, adopting new ways of doing things.  Those are the ones who I think can survive and thrive.   It’s going to take using all these things.  I don’t think there’s any one thing that, there’s any one solution that everybody will be able to apply.  It’s going to depend on your sector and what kind of alternatives you might be able to develop and how long will that take to develop?  There’s a lot of impatience about this supply chain resilience and reshoring.  I like to remind people that it took 20 to 25 years for China to capture the supply chain in many products.  And if you want to move the supply chain, we’re not talking about something that will happen in a year, or a couple of years.  You know, it’s kind of a two-way street.  People are finding they were far too over dependent on a particular sector, or particular manufacturer.  That says diversification is one route you can take in terms of I want to diversify my customers, I want to diversify the sectors that I serve.  We’ve seen a lot of pivots where firms have really moved into, moved into new areas, moved into new ways of serving customers as well.  So, it goes back to, I have to unfreeze my organizational ways of working and think about new things that I can do with those capabilities, new opportunities I can address.  Well, even software and services businesses have adopted global footprints as well.  And we’re not just talking about Asia or South Asia, but we’re seeing software companies having part of their footprint in Eastern Europe for example, or Ireland, or lots of different places.  I th ...

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords).generate(str(guest_text))

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Huggingface summarizer model
